# %% [markdown]
# # Load libraries

# %%
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.utils import shuffle
from statistics import mean
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import networkx as nx
import itertools
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# # Load data

# %%
blue=pd.read_csv('fad_blue_rnadata.csv').rename(columns={"Unnamed: 0": "Cells"})
blue.set_index("Cells", drop=True,inplace=True)
blue=blue.T
#^transpose because we want genes to be features

# %%
idx=blue.index 
y=blue['BlueFP']
x=blue.drop(['BlueFP'],axis=1)
#get top 200 genes from linear reg
genestokeep=pd.read_csv('data/top500_genes.csv').drop("Unnamed: 0",axis=1)['Genes']
x2=x.loc[:, x.columns.isin(genestokeep)]
genes=x2.columns
#set x and y
x1=x2.to_numpy()

# %% [markdown]
# # Parameter sweep
#
# Simple way of finding good parameters for each tree/forest

# %%
samp_split=[5,6,7,8] 
min_leaves=[2,3,4,5]
max_feat=[None,'sqrt']
scores=0
MSEs=999999999999999
for n in samp_split:
    for m in min_leaves:
        for o in max_feat:
            #split into train and test
            X_train, X_test, y_train, y_test = train_test_split(x1, y, test_size=0.2) 
            reg = RandomForestRegressor(min_samples_split=n, min_samples_leaf=m,max_features=o)
            reg.fit(X_train,y_train)
            scoretemp=reg.score(X_test,y_test) 
            y_pred=reg.predict(X_test)
            MSE_temp=np.sqrt(mean_squared_error(y_test,y_pred))#actually RMSE 
            print('min samples split value: '+str(n))
            print('min samples leaf value: '+str(m))
            print('max features value: '+str(o))
            print('Score: '+str(scoretemp))
            print('RMSE: '+str(MSE_temp))
            print()
            if MSEs>MSE_temp:
                MSEs=MSE_temp
                scores=scoretemp
                best_a=n
                best_b=m
                besto=o
                best_params=reg.get_params()
print('Best: ')
print('Score (D^2): '+str(scores)) 
print('Root mean squared error: '+str(MSEs)) 
print('Min samples split: '+str(best_a)) 
print('Min samples leaf: '+str(best_b)) 
print('Max features: '+str(besto))
# Out:
# min samples split value: 5
# min samples leaf value: 2
# max features value: None
# Score: 0.2281679218041991
# RMSE: 5.599498600835538
#
# min samples split value: 5
# min samples leaf value: 2
# max features value: sqrt
# Score: 0.2170098874547155
# RMSE: 5.454341730972069
#
# min samples split value: 5
# min samples leaf value: 3
# max features value: None
# Score: 0.23018664389377352
# RMSE: 5.616832700964723
#
# min samples split value: 5
# min samples leaf value: 3
# max features value: sqrt
# Score: 0.20068946601659066
# RMSE: 6.59989817629129
#
# min samples split value: 5
# min samples leaf value: 4
# max features value: None
# Score: 0.23188072390008052
# RMSE: 4.976770168291641
#
# min samples split value: 5
# min samples leaf value: 4
# max features value: sqrt
# Score: 0.17282014031199855
# RMSE: 5.9330645828722
#
# min samples split value: 5
# min samples leaf value: 5
# max features value: None
# Score: 0.17620945075871208
# RMSE: 6.55466998850303
#
# min samples split value: 5
# min samples leaf value: 5
# max features value: sqrt
# Score: 0.21909953437262397
# RMSE: 5.172135635497642
#
# min samples split value: 6
# min samples leaf value: 2
# max features value: None
# Score: 0.22840848697176985
# RMSE: 4.9712506079728636
#
# min samples split value: 6
# min samples leaf value: 2
# max features value: sqrt
# Score: 0.2213500686892348
# RMSE: 5.621189344138992
#
# min samples split value: 6
# min samples leaf value: 3
# max features value: None
# Score: 0.203077341943807
# RMSE: 5.5261535011063865
#
# min samples split value: 6
# min samples leaf value: 3
# max features value: sqrt
# Score: 0.2165985470552786
# RMSE: 5.758666100319531
#
# min samples split value: 6
# min samples leaf value: 4
# max features value: None
# Score: 0.12325147219738841
# RMSE: 7.260569718724551
#
# min samples split value: 6
# min samples leaf value: 4
# max features value: sqrt
# Score: 0.22138121702676894
# RMSE: 5.282097982621021
#
# min samples split value: 6
# min samples leaf value: 5
# max features value: None
# Score: 0.20350188396583657
# RMSE: 5.224064937034675
#
# min samples split value: 6
# min samples leaf value: 5
# max features value: sqrt
# Score: 0.2356128722522831
# RMSE: 4.617035790005896
#
# min samples split value: 7
# min samples leaf value: 2
# max features value: None
# Score: 0.2611494983783227
# RMSE: 6.114564853594902
#
# min samples split value: 7
# min samples leaf value: 2
# max features value: sqrt
# Score: 0.1765102814847761
# RMSE: 7.543432984880493
#
# min samples split value: 7
# min samples leaf value: 3
# max features value: None
# Score: 0.12248770172527534
# RMSE: 5.739494589372235
#
# min samples split value: 7
# min samples leaf value: 3
# max features value: sqrt
# Score: 0.14031265609233246
# RMSE: 7.446339902810644
#
# min samples split value: 7
# min samples leaf value: 4
# max features value: None
# Score: 0.17919463011577041
# RMSE: 6.859760619493328
#
# min samples split value: 7
# min samples leaf value: 4
# max features value: sqrt
# Score: 0.19398864969092666
# RMSE: 7.105343219306118
#
# min samples split value: 7
# min samples leaf value: 5
# max features value: None
# Score: 0.16652928421964153
# RMSE: 6.7764073064281884
#
# min samples split value: 7
# min samples leaf value: 5
# max features value: sqrt
# Score: 0.20625514249700505
# RMSE: 6.068558040703665
#
# min samples split value: 8
# min samples leaf value: 2
# max features value: None
# Score: 0.19932705267714013
# RMSE: 5.48817411667122
#
# min samples split value: 8
# min samples leaf value: 2
# max features value: sqrt
# Score: 0.19282616351487258
# RMSE: 5.817071387737059
#
# min samples split value: 8
# min samples leaf value: 3
# max features value: None
# Score: 0.26799456043059977
# RMSE: 6.437958661730242
#
# min samples split value: 8
# min samples leaf value: 3
# max features value: sqrt
# Score: 0.1758598265533916
# RMSE: 7.038424115431718
#
# min samples split value: 8
# min samples leaf value: 4
# max features value: None
# Score: 0.18438909868897446
# RMSE: 5.064578597428476
#
# min samples split value: 8
# min samples leaf value: 4
# max features value: sqrt
# Score: 0.17625192477362717
# RMSE: 6.627291139749917
#
# min samples split value: 8
# min samples leaf value: 5
# max features value: None
# Score: 0.24686864100580674
# RMSE: 6.490789213269337
#
# min samples split value: 8
# min samples leaf value: 5
# max features value: sqrt
# Score: 0.1439825171184166
# RMSE: 7.145595788859283
#
# Best:
# Score (D^2): 0.2356128722522831
# Root mean squared error: 4.617035790005896
# Min samples split: 6
# Min samples leaf: 5
# Max features: sqrt

# %%
best_params
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 5,
#  'min_samples_split': 6,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
numruns=10
scores=0
MSEs=0
for n in range(numruns):
    #split into train and test
    X_train2, X_test2, y_train, y_test = train_test_split(x1, y, test_size=0.2)
    scaler = preprocessing.StandardScaler().fit(X_train2)
    #scale using x_train model for both train & test
    X_train = scaler.transform(X_train2) 
    X_test= scaler.transform(X_test2) 
    reg = RandomForestRegressor(min_samples_split=best_a, min_samples_leaf=best_b,max_features=besto)
    reg.fit(X_train,y_train)
    scoretemp=reg.score(X_test,y_test)
    scores+=scoretemp
    y_pred=reg.predict(X_test)
    MSEs+=np.sqrt(mean_squared_error(y_test,y_pred))#actually RMSE
    plt.scatter(y_test,y_pred)
    plt.xlabel('Test data (Actual)')
    plt.ylabel('Predicted values')
    plt.title('Sample '+str(n)) 
    plt.show()
print('Average score (D^2): ')
print(scores/numruns)
print('Average root mean squared error: ')
print(MSEs/numruns)
# Out:
# Average score (D^2):
# 0.1903777539092931
# Average root mean squared error:
# 6.182850652007313
