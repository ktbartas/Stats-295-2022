# %% [markdown]
# # Load libraries

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn import preprocessing
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline 
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
import matplotlib as mpl
# Out:
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Kat\anaconda3\envs\tensor\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Load data

# %%
blue=pd.read_csv('fad_blue_rnadata.csv').rename(columns={"Unnamed: 0": "Cells"})
blue.set_index("Cells", drop=True,inplace=True)
blue=blue.T
#^transpose because we want genes to be features

# %%
idx=blue.index 
Y=blue['BlueFP']
x=blue.drop(['BlueFP'],axis=1)
#get top 200 genes from linear reg
genestokeep=pd.read_csv('data/top500_genes.csv').drop("Unnamed: 0",axis=1)['Genes']
x2=x.loc[:, x.columns.isin(genestokeep)]
genes=x2.columns
#set x and y
X=np.load('data/X_pca.npy')

# %% [markdown]
# # Support Vector Regression
#
# Try different kernels, parameters

# %%
epsilons=[0.05,0.1,0.2,0.3,0.4]
#linear kernel was best
Cs=[4,5,6,7]
gammas=['scale','auto']
funcs=['linear']
scores=0
MSEs=999999999999999
for n in Cs:
    for p in epsilons:
        for g in gammas:
            for f in funcs:
                #split into train and test
                X_train2, X_test2, y_train, y_test = train_test_split(X, Y, test_size=0.2)
                scaler = preprocessing.StandardScaler().fit(X_train2)
                #scale using x_train model for both train & test
                X_train = scaler.transform(X_train2) 
                X_test= scaler.transform(X_test2) 
                reg = SVR(kernel=f,C=n, epsilon=p,gamma=g)  
                reg.fit(X_train,y_train)
                scoretemp=reg.score(X_test,y_test) 
                y_pred=reg.predict(X_test)
                MSE_temp=np.sqrt(mean_squared_error(y_test,y_pred))
                print('C: '+str(n))
                print('Score: '+str(scoretemp))
                print('RMSE: '+str(MSE_temp))
                print('Epsilon: '+str(p))
                print('gamma: '+str(g))
                print('function type: '+str(f))
                print()
                if MSEs>MSE_temp:
                    MSEs=MSE_temp
                    scores=scoretemp
                    best_a=n
                    best_params=reg.get_params()
                    best_p=p
                    best_g=g
                    best_f=f
print('Best: ')
print('Score (D^2): '+str(scores)) 
print('Root mean squared error: '+str(MSEs)) 
print('C: '+str(best_a)) 
print('Epsilon: '+str(best_p)) 
print('gamma: '+str(best_g))
print('function: '+str(best_f))
# Out:
# C: 4
# Score: 0.06603084986638552
# RMSE: 6.584729594916208
# Epsilon: 0.05
# gamma: scale
# function type: linear
#
# C: 4
# Score: 0.05220775978184944
# RMSE: 7.087447779713421
# Epsilon: 0.05
# gamma: auto
# function type: linear
#
# C: 4
# Score: 0.14113778717383463
# RMSE: 4.7076077419232405
# Epsilon: 0.1
# gamma: scale
# function type: linear
#
# C: 4
# Score: 0.05773502681365372
# RMSE: 7.194748605567665
# Epsilon: 0.1
# gamma: auto
# function type: linear
#
# C: 4
# Score: 0.03366806672027256
# RMSE: 7.768435460825923
# Epsilon: 0.2
# gamma: scale
# function type: linear
#
# C: 4
# Score: 0.0739550243252598
# RMSE: 6.661632087448687
# Epsilon: 0.2
# gamma: auto
# function type: linear
#
# C: 4
# Score: 0.13786234719553248
# RMSE: 5.155968683812688
# Epsilon: 0.3
# gamma: scale
# function type: linear
#
# C: 4
# Score: 0.09343873302558992
# RMSE: 5.404392483007257
# Epsilon: 0.3
# gamma: auto
# function type: linear
#
# C: 4
# Score: 0.07157271161441003
# RMSE: 6.7401228945463165
# Epsilon: 0.4
# gamma: scale
# function type: linear
#
# C: 4
# Score: 0.06017781306412184
# RMSE: 8.100075048807774
# Epsilon: 0.4
# gamma: auto
# function type: linear
#
# C: 5
# Score: 0.10041190973084435
# RMSE: 5.835359110332376
# Epsilon: 0.05
# gamma: scale
# function type: linear
#
# C: 5
# Score: 0.07194613797907456
# RMSE: 6.4325713727219975
# Epsilon: 0.05
# gamma: auto
# function type: linear
#
# C: 5
# Score: 0.06616333489794068
# RMSE: 4.967409569233502
# Epsilon: 0.1
# gamma: scale
# function type: linear
#
# C: 5
# Score: 0.029155084827347633
# RMSE: 6.3776192737508435
# Epsilon: 0.1
# gamma: auto
# function type: linear
#
# C: 5
# Score: 0.07228173840920604
# RMSE: 6.094459949769394
# Epsilon: 0.2
# gamma: scale
# function type: linear
#
# C: 5
# Score: 0.0738696771214774
# RMSE: 5.730367971037023
# Epsilon: 0.2
# gamma: auto
# function type: linear
#
# C: 5
# Score: 0.09121166701618999
# RMSE: 5.831754571790256
# Epsilon: 0.3
# gamma: scale
# function type: linear
#
# C: 5
# Score: 0.07297819442347431
# RMSE: 6.310726985952051
# Epsilon: 0.3
# gamma: auto
# function type: linear
#
# C: 5
# Score: 0.061142380121052
# RMSE: 6.562553955588042
# Epsilon: 0.4
# gamma: scale
# function type: linear
#
# C: 5
# Score: 0.09126611740084767
# RMSE: 5.249603137131977
# Epsilon: 0.4
# gamma: auto
# function type: linear
#
# C: 6
# Score: 0.055902482243450735
# RMSE: 7.014369478950786
# Epsilon: 0.05
# gamma: scale
# function type: linear
#
# C: 6
# Score: 0.04599535260631227
# RMSE: 6.379455530290956
# Epsilon: 0.05
# gamma: auto
# function type: linear
#
# C: 6
# Score: 0.056360107277986904
# RMSE: 6.358138822372581
# Epsilon: 0.1
# gamma: scale
# function type: linear
#
# C: 6
# Score: 0.0788819508199674
# RMSE: 6.042882203463744
# Epsilon: 0.1
# gamma: auto
# function type: linear
#
# C: 6
# Score: 0.08387822531136702
# RMSE: 5.883754044424896
# Epsilon: 0.2
# gamma: scale
# function type: linear
#
# C: 6
# Score: 0.07467506632328924
# RMSE: 6.952761664348642
# Epsilon: 0.2
# gamma: auto
# function type: linear
#
# C: 6
# Score: 0.05248042048316026
# RMSE: 6.6489502382045504
# Epsilon: 0.3
# gamma: scale
# function type: linear
#
# C: 6
# Score: 0.06439202427277779
# RMSE: 7.085085504483811
# Epsilon: 0.3
# gamma: auto
# function type: linear
#
# C: 6
# Score: 0.078391100211191
# RMSE: 6.08468004372796
# Epsilon: 0.4
# gamma: scale
# function type: linear
#
# C: 6
# Score: 0.0643579466462938
# RMSE: 7.376431594072362
# Epsilon: 0.4
# gamma: auto
# function type: linear
#
# C: 7
# Score: 0.07013072047313185
# RMSE: 6.589739817830579
# Epsilon: 0.05
# gamma: scale
# function type: linear
#
# C: 7
# Score: 0.059608241841934584
# RMSE: 7.074770324649427
# Epsilon: 0.05
# gamma: auto
# function type: linear
#
# C: 7
# Score: 0.07318592942638069
# RMSE: 5.982044488664525
# Epsilon: 0.1
# gamma: scale
# function type: linear
#
# C: 7
# Score: 0.04718836631707857
# RMSE: 6.56358786294994
# Epsilon: 0.1
# gamma: auto
# function type: linear
#
# C: 7
# Score: 0.06626923901018456
# RMSE: 5.761518685074997
# Epsilon: 0.2
# gamma: scale
# function type: linear
#
# C: 7
# Score: 0.10576670935164889
# RMSE: 6.620707317097568
# Epsilon: 0.2
# gamma: auto
# function type: linear
#
# C: 7
# Score: 0.06036087272642454
# RMSE: 6.547734788911794
# Epsilon: 0.3
# gamma: scale
# function type: linear
#
# C: 7
# Score: 0.08502550948173382
# RMSE: 5.517701758827908
# Epsilon: 0.3
# gamma: auto
# function type: linear
#
# C: 7
# Score: 0.06277121979107747
# RMSE: 7.193029403294149
# Epsilon: 0.4
# gamma: scale
# function type: linear
#
# C: 7
# Score: 0.06968799333185971
# RMSE: 7.442814658529162
# Epsilon: 0.4
# gamma: auto
# function type: linear
#
# Best:
# Score (D^2): 0.14113778717383463
# Root mean squared error: 4.7076077419232405
# C: 4
# Epsilon: 0.1
# gamma: scale
# function: linear

# %%
numruns=10
scores=0
MSEs=0
for n in range(numruns):
    #split into train and test
    X_train2, X_test2, y_train, y_test = train_test_split(X, Y, test_size=0.2)
    scaler = preprocessing.StandardScaler().fit(X_train2)
    #scale using x_train model for both train & test
    X_train = scaler.transform(X_train2) 
    X_test= scaler.transform(X_test2) 
    reg = SVR(kernel=best_f,C=best_a, epsilon=best_p,gamma=best_g)  
    reg.fit(X_train,y_train)
    scoretemp=reg.score(X_test,y_test)
    scores+=scoretemp
    y_pred=reg.predict(X_test)
    MSEs+=np.sqrt(mean_squared_error(y_test,y_pred))
    plt.scatter(y_test,y_pred)
    plt.xlabel('Test data (Actual)')
    plt.ylabel('Predicted values')
    plt.title('Sample '+str(n))
    plt.show()
print('Average score (D^2): ')
print(scores/numruns)
print('Average root mean squared error: ')
print(MSEs/numruns)
# Out:
# Average score (D^2):
# 0.06388952296492605
# Average root mean squared error:
# 6.440994401265769
